# %% [markdown]
# <a href="https://colab.research.google.com/github/suryasis-hub/NLP/blob/main/ParseAndRemoveHTMLTag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/Rahul_Dravid"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
import re
pattern = re.compile(r'<.*?>')

    # Use the sub() function to replace HTML tags with an empty string
content_str = response.content.decode('utf-8')
clean_text = re.sub(pattern, '', content_str)
print(clean_text)
# Out:
# Rahul Dravid - Wikipedia
# ...
